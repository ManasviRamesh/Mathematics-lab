# %%
var('x,y')
# Out:
# (x, y)

# %%
f(x)=x^2+3*cos(x)

# %%
f(3)
# Out:
# 3*cos(3) + 9

# %%
f(3).n()
# Out:
# 6.03002251019866

# %%
f(2).n(2)
# Out:
# 3.0

# %%
pf=plot(f,-3,3,color='red',linestyle='--')
plot(pf)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g(x)=sin(x)+exp(x)
pg=plot(g,-3,3)
pf+pg
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
f(x,y)=sin(x+y)*x*cos(x-y)
f(0,1)
# Out:
# 0

# %%
pf1=plot3d(f(x,y),(x,-2,2),(y,-2,2),color='green',opacity=.3)

# %%
p0=(0,0,f(0,0))
pp0=point3d(p0,size=80)

# %%
pf1+pp0
# Out:
# Graphics3d Object

# %%
pf2=plot3d(f(x,y),(x,-3,3),(y,-4,4),color='green',opacity=.3)

# %%
pf3=plot3d(f(x,y),(x,-5,5),(y,-2,2),color='blue',opacity=.5)

# %%
pf2+pf3
# Out:
# Graphics3d Object

# %%
p1=(1,0,f(0,0))
pp1=point3d(p1,size=80,color='black')
p2=(3,2,f(0,0))
pp2=point3d(p1,size=80,color='white')
p3=(2,3,f(0,0))
pp3=point3d(p1,size=80,color='red')
p4=(5,3,f(0,0))
pp4=point3d(p1,size=80,color='yellow')

# %%
pp1+pf2+pf3
# Out:
# Graphics3d Object

# %%
pp2+pf2+pf3
# Out:
# Graphics3d Object

# %%
pp3+pf2+pf3
# Out:
# Graphics3d Object

# %%
pp4+pf2+pf3
# Out:
# Graphics3d Object

# %%
g(x)=f(x,2)

# %%
show(f(x,y))
# Out:
# x*cos(x - y)*sin(x + y)

# %%
show(g(x))
# Out:
# x*cos(x - 2)*sin(x + 2)

# %%
plot(g,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot3d(g(x),(x,-2,2),(y,0,2))
# Out:
# Graphics3d Object

# %%
pg_=plot3d(g(x),(x,-2,2),(y,0,2),color='red',opacity=.3)

# %%
pf1+pg_
# Out:
# Graphics3d Object

# %%
p01=parametric_plot3d((x,1,f(x,1)),(x,-2,2),thickness=7)+pf1

# %%
p1=parametric_plot3d((1,y,f(1,y)),(y,-2,2),thickness=8,color='red')+pf1

# %%
p01+p1+parametric_plot3d((x,x,f(x,x)),(x,-2,2),color='orange',thickness=9)+pf1
# Out:
# Graphics3d Object
